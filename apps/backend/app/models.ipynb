# %%
from transformers import pipeline
pipe = pipeline("zero-shot-image-classification", model="google/siglip2-base-patch32-256")
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Device set to use cpu

# %%
candidates = ["Screenshot of user watching a video", "screenshot of user playing a video game", "screenshot of user working", "screenshot of the home screen"]

# %%
pipe(
    "https://www.wikihow.com/images/thumb/6/66/Get-a-Screenshot-from-a-YouTube-Video-Step-24.jpg/v4-460px-Get-a-Screenshot-from-a-YouTube-Video-Step-24.jpg",
    candidate_labels=candidates,
)
# Out:
# [{'score': 0.018882200121879578,
#   'label': 'Screenshot of user watching a video'},
#  {'score': 0.0006039810250513256, 'label': 'screenshot of user working'},
#  {'score': 0.00024631290580146015,
#   'label': 'screenshot of user playing a video game'}]

# %%
pipe(
    "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTjst9QMvx8yIuZlFHqZi1oAtizBLYN0Ysx7g&s",
    candidate_labels=candidates,
)
# Out:
# [{'score': 0.0009339502430520952,
#   'label': 'screenshot of user playing a video game'},
#  {'score': 8.974350748758297e-06, 'label': 'screenshot of user working'},
#  {'score': 3.6248095511837164e-06,
#   'label': 'Screenshot of user watching a video'}]

# %%
img_url = "data:image/jpeg;base64,..."
pipe(
    img_url,
    candidate_labels=candidates,
)
# Out:
# [{'score': 0.0018889775965362787, 'label': 'screenshot of user working'},
#  {'score': 0.0010506410617381334,
#   'label': 'screenshot of user playing a video game'},
#  {'score': 0.0006307028234004974,
#   'label': 'Screenshot of user watching a video'},
#  {'score': 0.0006253958563320339, 'label': 'screenshot of the home screen'}]
